# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from scipy.optimize import fsolve
plt.rcParams.update({
  "text.usetex": True,
  "font.family": "serif"
})




π = np.pi
Ω_cdm = 0.85
G = 6.67e-11                # in units of m^3⋅kg^−1⋅s^−2
t_i = 2.358e5                # in units of seconds
t_eq = 1.5923e12            # in units of seconds
ρ_eq = 2.1548e-16          # in units of kg m^-3
M_solar = 1.989e30        # in units of kg
c = 3e8                 #in units of m/s
A = 1.495e11                 # Astronomical unit
pc = 3.085e16               # in unist of meter. 
yr = 3.154e7              # in units of seconds
a_eq = 2.9374e-4

h_bar = 1.0545718e-34        # reduced Planck constant in unkits of J.s
h_bar_c = h_bar * c
eV = 1.60218e-19               #in units of J
eV_to_kg = 1.7826e-36             #in units of kg
m_FDM_eV = 1e-22     #in units of eV/c²
m_FDM = m_FDM_eV * eV_to_kg      # Mass of FDM boson in units of kg







def j_fdm(n, t):
    r = n[0]
    v = n[1]
    d2r_dt2 = -(G * M_pbh)/(r**2) +  ((2*gamma  - gamma**2) * (h_bar**2))/(4 * (m_FDM**2) * (r**3)) - r/(4*(t**2))
    return [v, d2r_dt2]



gamma = 1e-10  # Power-law density parameter in Eq. (3.2) of https://arxiv.org/abs/1808.08219
M_pbh = 100 * M_solar  # PBH mass in kg

# %%
fig,ax = plt.subplots(1, figsize = (16, 6))
plt.rc('lines', linewidth = 2.3)
plt.rcParams['font.family'] = 'serif'
plt.tick_params(axis = 'both', right=True, top=True, which = 'minor', width= 1.2, length = 4, direction = 'in')
plt.tick_params(axis = 'both', right=True, top=True, which = 'major', width= 1.2, length = 9, direction = 'in')







r_i = 1e10       # Initial distance of FDM shell, in units of meters
t_i = 2.358e5    # Initial time in units of second
ps = np.linspace(t_i, 1e8*t_i, 10000)  
z0 = [r_i, (r_i / (2 * t_i))]  #Initial conditions with H(t)=1/(2t) in RD
ns = odeint(j_fdm, z0, ps)
zs = ns[:, 0]
z_max = np.max(zs)
p_max = ps[np.argmax(zs)]
print("r_max =", '%.4e' % z_max, "m", ",", "t_max =", '%.4e' % p_max, "s")


plt.plot(ps, zs, 'C0')



plt.xticks(fontsize = 25)
plt.yticks(fontsize = 25)
plt.xlabel('Time, t \,[s]', fontsize = 29)
plt.ylabel('Distance, r \,[m]', fontsize = 29, labelpad = 9)
plt.title(r'Distance of FDM Shell from PBH $\,\mathrm{M_{pbh}} =  100\, \mathrm{M_{\odot}},\,r_i = 10^{10}\, \mathrm{m} $', fontsize = 31, pad = 11)
plt.show()
# Out:
# r_max = 1.8170e+19 m , t_max = 2.3580e+13 s

# %%
fig,ax = plt.subplots(1, figsize = (16, 6))
plt.rc('lines', linewidth = 2.3)
plt.rcParams['font.family'] = 'serif'
plt.tick_params(axis = 'both', right=True, top=True, which = 'minor', width= 1.2, length = 4, direction = 'in')
plt.tick_params(axis = 'both', right=True, top=True, which = 'major', width= 1.2, length = 9, direction = 'in')



r_i = 1e11    # Initial distance of FDM shell, in units of meters
t_i = 2.358e5  # Initial time in units of second
ps = np.linspace(t_i, 1e9*t_i, 10000)  
z0 = [r_i, (r_i / (2 * t_i))]  # Initial conditions with H(t)=1/(2t) in RD
ns = odeint(j_fdm, z0, ps)
zs = ns[:, 0]
z_max = np.max(zs)
p_max = ps[np.argmax(zs)]
print("r_max =", '%.4e' % z_max, "m", ",", "t_max =", '%.4e' % p_max, "s")


plt.plot(ps, zs, 'C1')

plt.xticks(fontsize = 25)
plt.yticks(fontsize = 25)
plt.xlabel('Time, t \,[s]', fontsize = 29)
plt.ylabel('Distance, r \,[m]', fontsize = 29, labelpad = 9)
plt.title(r'Distance of FDM Shell from PBH $\,\mathrm{M_{pbh}} =  100\, \mathrm{M_{\odot}},\,r_i = 10^{11}\, \mathrm{m} $', fontsize = 31, pad = 11)
plt.show()
# Out:
# r_max = 6.4635e+18 m , t_max = 2.3580e+14 s

# %%
fig,ax = plt.subplots(1, figsize = (16, 6))
plt.rc('lines', linewidth = 2.3)
plt.rcParams['font.family'] = 'serif'
plt.tick_params(axis = 'both', right=True, top=True, which = 'minor', width= 1.2, length = 4, direction = 'in')
plt.tick_params(axis = 'both', right=True, top=True, which = 'major', width= 1.2, length = 9, direction = 'in')



r_i = 1e12    # Initial distance of FDM shell, in units of meters
t_i = 2.358e5  # Initial time in units of second
ps = np.linspace(t_i, 1e11*t_i, 100000)  
z0 = [r_i, (r_i / (2 * t_i))]  # Initial conditions with H(t)=1/(2t)
ns = odeint(j_fdm, z0, ps)
zs = ns[:, 0]
z_max = np.max(zs)
p_max = ps[np.argmax(zs)]
print("r_max =", '%.4e' % z_max, "m", ",", "t_max =", '%.4e' % p_max, "s")


plt.plot(ps, zs, 'C2')

plt.xticks(fontsize = 25)
plt.yticks(fontsize = 25)
plt.xlabel('Time, t \,[s]', fontsize = 29)
plt.ylabel('Distance, r \,[m]', fontsize = 29, labelpad = 9)
plt.title(r'Distance of FDM Shell from PBH $\,\mathrm{M_{pbh}} =  100\, \mathrm{M_{\odot}},\,r_i = 10^{12}\, \mathrm{m} $', fontsize = 31, pad = 11)
plt.show()
# Out:
# r_max = 7.1318e+18 m , t_max = 2.3580e+16 s

# %%
fig,ax = plt.subplots(1, figsize = (16, 6))
plt.rc('lines', linewidth = 2.3)
plt.rcParams['font.family'] = 'serif'
plt.tick_params(axis = 'both', right=True, top=True, which = 'minor', width= 1.2, length = 4, direction = 'in')
plt.tick_params(axis = 'both', right=True, top=True, which = 'major', width= 1.2, length = 9, direction = 'in')



r_i = 5e12    # Initial distance of FDM shell, in units of meters
t_i = 2.358e5  # Initial time in units of second
ps = np.linspace(t_i, 1.8e9*t_i, 10000)  
z0 = [r_i, (r_i/(2 * t_i))]  # Initial conditions with H(t)=1/(2t)
ns = odeint(j_fdm, z0, ps)
zs = ns[:, 0]
z_max = np.max(zs)
p_max = ps[np.argmax(zs)]
print("r_max =", '%.4e' % z_max, "m", ",", "t_max =", '%.4e' % p_max, "s")


plt.plot(ps, zs, 'C3')

plt.xticks(fontsize = 25)
plt.yticks(fontsize = 25)
plt.xlabel('Time, t \,[s]', fontsize = 29)
plt.ylabel('Distance, r \,[m]', fontsize = 29, labelpad = 9)
plt.title(r'Distance of FDM Shell from PBH $\,\mathrm{M_{pbh}} =  100\, \mathrm{M_{\odot}},\,r_i = 5\times 10^{12}\, \mathrm{m} $', fontsize = 31, pad = 11)
plt.show()
# Out:
# r_max = 9.6920e+16 m , t_max = 1.8249e+14 s

# %%
fig,ax = plt.subplots(1, figsize = (16, 6))
plt.rc('lines', linewidth = 2.3)
plt.rcParams['font.family'] = 'serif'
plt.tick_params(axis = 'both', right=True, top=True, which = 'minor', width= 1.2, length = 4, direction = 'in')
plt.tick_params(axis = 'both', right=True, top=True, which = 'major', width= 1.2, length = 9, direction = 'in')



r_i = 1e13    # Initial distance of FDM shell, in units of meters
t_i = 2.358e5  # Initial time in units of second
ps = np.linspace(t_i, 3.8e10*t_i, 10000)  
z0 = [r_i, (r_i/(2 * t_i))]  # Initial conditions with H(t)=1/(2t)
ns = odeint(j_fdm, z0, ps)
zs = ns[:, 0]
z_max = np.max(zs)
p_max = ps[np.argmax(zs)]
print("r_max =", '%.4e' % z_max, "m", ",", "t_max =", '%.4e' % p_max, "s")


plt.plot(ps, zs, 'C4')

plt.xticks(fontsize = 25)
plt.yticks(fontsize = 25)
plt.xlabel('Time, t \,[s]', fontsize = 29)
plt.ylabel('Distance, r \,[m]', fontsize = 29, labelpad = 9)
plt.title(r'Distance of FDM Shell from PBH $\,\mathrm{M_{pbh}} =  100\, \mathrm{M_{\odot}},\,r_i = 10^{13}\, \mathrm{m} $', fontsize = 31, pad = 11)
plt.show()
# Out:
# r_max = 7.2181e+17 m , t_max = 3.6213e+15 s

# %%
fig,ax = plt.subplots(1, figsize = (16, 6))
plt.rc('lines', linewidth = 2.3)
plt.rcParams['font.family'] = 'serif'
plt.tick_params(axis = 'both', right=True, top=True, which = 'minor', width= 1.2, length = 4, direction = 'in')
plt.tick_params(axis = 'both', right=True, top=True, which = 'major', width= 1.2, length = 9, direction = 'in')



r_i = 1e14    # Initial distance of FDM shell, in units of meters
t_i = 2.358e5  # Initial time in units of second
ps = np.linspace(t_i, 1.87e11*t_i, 10000)  
z0 = [r_i, (r_i/(2 * t_i))]  # Initial conditions with H(t)=1/(2t)
ns = odeint(j_fdm, z0, ps)
zs = ns[:, 0]
z_max = np.max(zs)
p_max = ps[np.argmax(zs)]
print("r_max =", '%.4e' % z_max, "m", ",", "t_max =", '%.4e' % p_max, "s")


plt.plot(ps, zs, 'C5')

plt.xticks(fontsize = 25)
plt.yticks(fontsize = 25)
plt.xlabel('Time, t \,[s]', fontsize = 29)
plt.ylabel('Distance, r \,[m]', fontsize = 29, labelpad = 9)
plt.title(r'Distance of FDM Shell from PBH $\,\mathrm{M_{pbh}} =  100\, \mathrm{M_{\odot}},\,r_i = 10^{14}\, \mathrm{m} $', fontsize = 31, pad = 11)
plt.show()
# Out:
# r_max = 4.3188e+19 m , t_max = 4.4095e+16 s

# %%
fig,ax = plt.subplots(1, figsize = (16, 6))
plt.rc('lines', linewidth = 2.3)
plt.rcParams['font.family'] = 'serif'
plt.tick_params(axis = 'both', right=True, top=True, which = 'minor', width= 1.2, length = 4, direction = 'in')
plt.tick_params(axis = 'both', right=True, top=True, which = 'major', width= 1.2, length = 9, direction = 'in')



r_i = 1e15    # Initial distance of FDM shell, in units of meters
t_i = 2.358e5  # Initial time in units of second
ps = np.linspace(t_i, 1.87e11*t_i, 10000)  
z0 = [r_i, (r_i/(2 * t_i))]  # Initial conditions with H(t)=1/(2t)
ns = odeint(j_fdm, z0, ps)
zs = ns[:, 0]
z_max = np.max(zs)
p_max = ps[np.argmax(zs)]
print("r_max =", '%.4e' % z_max, "m", ",", "t_max =", '%.4e' % p_max, "s")


plt.plot(ps, zs, 'C6')

plt.xticks(fontsize = 25)
plt.yticks(fontsize = 25)
plt.xlabel('Time, t \,[s]', fontsize = 29)
plt.ylabel('Distance, r \,[m]', fontsize = 29, labelpad = 9)
plt.title(r'Distance of FDM Shell from PBH $\,\mathrm{M_{pbh}} =  100\, \mathrm{M_{\odot}},\,r_i = 10^{15}\, \mathrm{m} $', fontsize = 31, pad = 11)
plt.show()
# Out:
# r_max = 4.3243e+20 m , t_max = 4.4095e+16 s

# %%
# Turnaround radius of FDM shell when the quantum pressure 
# of FDM Bosons is considered negligible under the assumption 
# that the typical size of the solitonic radius should always much 
# smaller than the typical size of the Turnaround radius of FDM shell around a PBH. 
# This eq. is similar to eq.(5) in reference
# "WIMPs and stellar-mass primordial black holes are incompatible".
# Also calculated as the Turnaround radius of CDM shells in the first project. 



# Turnaround radius of the FDM shell around PBH of mass M_pbh.



# Ignoring the gamma term for much smaller values of gamma which coincides
# with the turnaround of CDM shell around the PBH of mass M
def r_turnaround_approx(t):  
    return (4 * G * M_pbh * (t**(2)))**(1/3)



def r_turnaround_full(t):
    #M_sol_max = (h_bar_c)/ (2 * G * m_FDM)
    #r_sol =  (h_bar**2)/(2 * G * M_sol_max * (m_FDM**2)) 
    def expression(r_ta):
        return (r_ta**4) + (4 * G * M_pbh* (t**2) * r_ta) - ((2*gamma - gamma**2) * (h_bar**2) * (t**2))/(m_FDM**2)
    r_ta_initial = r_turnaround_approx(t) * 0.01     # 1e-3 * r_sol 
    r_ta_solution = fsolve(expression, r_ta_initial)
    return r_ta_solution[0]






M_pbh = 100 * M_solar
t = np.linspace(t_i, t_eq, 10000)


fig,ax = plt.subplots(1, figsize = (18, 8))
plt.rc('lines', linewidth = 2.6)
plt.rcParams['font.family'] = 'serif'
plt.tick_params(axis = 'both', right=True, top=True, which = 'minor', width= 1.2, length = 4, direction = 'in')
plt.tick_params(axis = 'both', right=True, top=True, which = 'major', width= 1.2, length = 9, direction = 'in')


plt.loglog(t, [r_turnaround_full(t) for t in t],'r', linestyle = '-')
plt.loglog(t, r_turnaround_approx(t),'k', linestyle = ':')

ax.tick_params(axis='x', pad = 9.9)
ax.tick_params(axis='y', pad = 9.9)

plt.xticks(fontsize = 31)
plt.yticks(fontsize = 31)
plt.xlabel('Time, t \,[s]', fontsize = 34)
plt.ylabel('Turnaround radius, $r_\mathrm{ta}$ \,[m]', fontsize = 34, labelpad = 11)

plt.legend([ '$r_\mathrm{ta,\,full}$', '$r_\mathrm{ta,\,approx}$'],
            title_fontsize = 20, loc = 'lower right', prop = {"size":36})

plt.title(r'Turnaround radius of FDM Shell $,\mathrm{M_{pbh}} =  100\, \mathrm{M_{\odot}}, \gamma = 10^{-10}$', fontsize = 36, pad = 11)
plt.savefig("r_ta.pdf", bbox_inches = "tight")
plt.show()

# %%
# Dynamics of the various shells of DM halo around a PBH of mass, M_PBH=100 
# solar mass at different initial radii

fig, ax = plt.subplots(1, figsize=(10.3, 7.3))
plt.tick_params(axis = 'both', right=True, top=True, which = 'minor', width= 1, length = 2)
plt.tick_params(axis = 'both', right=True, top=True, which = 'major', width= 1.1, length = 6)
plt.rc('lines', linewidth = 3.4)
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'


yr = 3.154e7               # in units of seconds
M_PBH = 100 * M_solar           # in units of kg
T_eq = (t_eq/yr)             # t_eq = 50485 yr



def j_cdm(n, t):
    r = n[0]
    v = n[1]
    d2r_dt2 = -((G * M_pbh)/(r**2)) -(r/(4*(t**2)))
    return [v, d2r_dt2]



r_i = np.geomspace(1e12, 1e13, 6)
#r_i = [1.00000000e+12 1.77827941e+12 3.16227766e+12 5.62341325e+12
 #1.00000000e+13] in meters
#r_i = ([3.24149109e-05, 5.13741716e-05, 8.14225748e-05, 1.29046084e-04,
       # 2.04524261e-04, 3.24149109e-04]) in pc

r_i_list = r_i.tolist()
t_f_list = [ 1e10*t_i, 2.65e11*t_i, 8.5e9*t_i, 1.52e9*t_i ,  3.9e9*t_i , 3.8e10*t_i ]


colors = ['C0','C1','C2','C3', 'C4','C5'] 

for i, (r_i, t_f, c) in enumerate(zip(r_i_list, t_f_list, colors)):
    z0 = [r_i, (r_i/(2*t_i))]                      
    ps = np.linspace(t_i, t_f, 100000) 
    ns = odeint(j_fdm, z0, ps)
    zs = ns[:,0]
    ps_yr = ps/yr
    zs_pc = zs/pc
    plt.loglog(ps_yr, zs_pc, c = c)
    
    
    
    


ax.axvline(x = T_eq, color = 'c', linestyle = '--')
t_arr = np.linspace(1e10*t_i, 4e10*t_i, 100000)
t = np.linspace(t_i, t_eq, 10000)
#ax.loglog(t/yr, [r_turnaround_full(t)/pc for t in t],'k', linestyle = ':')
#ax.loglog(t/yr, r_turnaround_approx(t)/pc,'k', linestyle = ':')



ax.tick_params(axis='x', pad= 8.8)
ax.tick_params(axis='y', pad= 8.8)
plt.xticks(fontsize= 38)
plt.yticks(fontsize= 38)
plt.xlabel('$t \,$ [yr]',fontsize= 41.5, labelpad = 15)
plt.ylabel('$r\,$ [pc]',fontsize= 41.5, labelpad = 15)

plt.legend( [r'$3.24\times 10^{-5}$', r'$5.13\times 10^{-5}$', r'$8.14\times 10^{-5}$', r'$1.29\times 10^{-4}$', r'$2.04\times 10^{-4}$', r'$3.24\times 10^{-4}$'],
           prop = {'size':17}, loc = 'upper left',shadow = True, title = '$r_{i}\, \mathrm{[pc]}$' ,title_fontsize = 30,
           facecolor = 'white',fontsize = 44)



plt.title("$M_\mathrm{pbh} = 100 \, \mathrm{M_{\odot}}$", pad = 15, fontsize = 42)
plt.savefig("FDM_shell.pdf", bbox_inches = "tight")
plt.show()

# %%
# Dynamics of the various shells of DM halo around a PBH of mass, M_PBH=100 
# solar mass at different initial radii

fig, ax = plt.subplots(1, figsize=(10.3, 7.3))
plt.tick_params(axis = 'both', right=True, top=True, which = 'minor', width= 1, length = 2)
plt.tick_params(axis = 'both', right=True, top=True, which = 'major', width= 1.1, length = 6)
plt.rc('lines', linewidth = 3.4)
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'


yr = 3.154e7               # in units of seconds
M_PBH = 100 * M_solar           # in units of kg
T_eq = (t_eq/yr)             # t_eq = 50485 yr



def j_cdm(n, t):
    r = n[0]
    v = n[1]
    d2r_dt2 = -((G * M_pbh)/(r**2)) -(r/(4*(t**2)))
    return [v, d2r_dt2]



r_i = np.geomspace(1e12, 1e13, 6)
#r_i = [1.00000000e+12 1.77827941e+12 3.16227766e+12 5.62341325e+12
 #1.00000000e+13]

r_i_list = r_i.tolist()
t_f_list = [ 1e10*t_i, 2.65e11*t_i, 8.5e9*t_i, 1.52e9*t_i ,  3.9e9*t_i , 3.8e10*t_i ]


colors = ['C0','C1','C2','C3', 'C4','C5'] 

for i, (r_i, t_f, c) in enumerate(zip(r_i_list, t_f_list, colors)):
    z0 = [r_i, (r_i/(2*t_i))]                      
    ps = np.linspace(t_i, t_f, 100000) 
    ns = odeint(j_fdm, z0, ps)
    zs = ns[:,0]
    ps_yr = ps/yr
    zs_pc = zs/pc
    plt.loglog(ps_yr, zs_pc, c = c)
    
    
    
    
t_f1_list = [7.3e5, 1.2e7, 1.96e9, 7.96e11 , t_eq]
for i, (r_i, t_f, c) in enumerate(zip(r_i_list, t_f1_list, colors)):
    z0 = [r_i, (r_i/(2*t_i))]                     
    ps = np.linspace(t_i, t_f, 100000)
    ns_cdm = odeint(j_cdm, z0, ps)
    zs_cdm = ns_cdm[:,0]
    zs_cdm_pc = zs_cdm/pc
    ps_yr = ps/yr
 
    plt.loglog(ps_yr, zs_cdm_pc, c = c, ls = '-.')

    


ax.axvline(x = T_eq, color = 'c', linestyle = '--')

    
ax.tick_params(axis='x', pad= 8.8)
ax.tick_params(axis='y', pad= 8.8)
plt.xticks(fontsize= 38)
plt.yticks(fontsize= 38)
plt.xlabel('$t \,$ [yr]',fontsize= 41.5, labelpad = 15)
plt.ylabel('$r\,$ [pc]',fontsize= 41.5, labelpad = 15)
plt.legend( [r'$10^{-12}$', r'$1.77\times 10^{-12}$', r'$3.16\times 10^{-12}$', r'$5.62\times 10^{-12}$','33', r'$ 10^{-13}$'
              ],prop = {'size':10.1},
              loc = 'upper left',shadow = True, title = '$r_{i}\, [pc]$' ,
           facecolor = 'white',fontsize = 44)
plt.setp(ax.get_legend().get_texts(), fontsize='28.5')
plt.title("$M_\mathrm{pbh} = 100 \, \mathrm{M_{\odot}}$", pad = 15, fontsize = 42)
plt.savefig("FDM_shell.pdf", bbox_inches = "tight")
plt.show()
